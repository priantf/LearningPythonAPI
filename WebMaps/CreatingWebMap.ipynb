# %%
from arcgis.gis import GIS
from arcgis.mapping import WebMap
from arcgis.features import FeatureLayer

# %%
# Realizar login no Portal

url_portal = "https://org_url/portal"
user = "user"
pwd = "*******"

gis = GIS(url_portal, user, pwd)

# %%
# Instanciar o serviço do server

url_service = "https://sampleserver6.arcgisonline.com/arcgis/rest/services/CommercialDamageAssessment/FeatureServer/0"
feature_layer = FeatureLayer(url_service)

# %%
# Criando um mapa

webmap = WebMap()

# %%
# Adicionando a camada no mapa

webmap.add_layer(feature_layer, {'visibility': True, 'title':'Teste Python API'})
# Out:
# True

# %%
# Função para desabilitar campos da popup + exemplo de json com atributos

def disable_fields(item, fields2disable):
    field_infos = item['popupInfo']['fieldInfos']
    
    for field in field_infos:
        if field['fieldName'] in fields2disable:
            field["visible"] = False

'''
Exemplo de fieldInfos

[
   {
      "fieldName":"objectid",
      "label":"OBJECTID",
      "isEditable":false,
      "visible":true
   },
   {
      "fieldName":"incidentid",
      "label":"Incident Number",
      "isEditable":true,
      "visible":true
   },
   {
      "fieldName":"incidentnm",
      "label":"Incident Name",
      "isEditable":true,
      "visible":true
   },
   {
      "fieldName":"inspectid",
      "label":"Inspector ID",
      "isEditable":true,
      "visible":true
   },
   {
      "fieldName":"inspector",
      "label":"Inspector",
      "isEditable":true,
      "visible":true
   },
   {
      "fieldName":"inspemail",
      "label":"Inspector's Email Address",
      "isEditable":true,
      "visible":true
   },
   {
      "fieldName":"inspphone",
      "label":"Inspector's Phone Number",
      "isEditable":true,
      "visible":true
   },
   {
      "fieldName":"affil",
      "label":"Affiliation",
      "isEditable":true,
      "visible":true
   },
   {
      "fieldName":"inspdate",
      "label":"Inspection Date Time",
      "isEditable":true,
      "visible":true
   },
   {
      "fieldName":"placename",
      "label":"Name of Business",
      "isEditable":true,
      "visible":true
   },
   {
      "fieldName":"firstname",
      "label":"Contact First Name",
      "isEditable":true,
      "visible":true
   },
   {
      "fieldName":"lastname",
      "label":"Contact Last Name",
      "isEditable":true,
      "visible":true
   },
   {
      "fieldName":"fulladdr",
      "label":"Full Address",
      "isEditable":true,
      "visible":true
   },
   {
      "fieldName":"pstlcity",
      "label":"Postal City",
      "isEditable":true,
      "visible":true
   },
   {
      "fieldName":"pstlzip5",
      "label":"Postal Zip 5",
      "isEditable":true,
      "visible":true
   },
   {
      "fieldName":"siteid",
      "label":"Site ID",
      "isEditable":true,
      "visible":true
   },
   {
      "fieldName":"parcelid",
      "label":"Parcel Identification Number",
      "isEditable":true,
      "visible":true
   },
   {
      "fieldName":"usngcoord",
      "label":"USNG Coordinate",
      "isEditable":true,
      "visible":true
   },
   {
      "fieldName":"homephone",
      "label":"Home Phone",
      "isEditable":true,
      "visible":true
   },
   {
      "fieldName":"workphone",
      "label":"Work Phone",
      "isEditable":true,
      "visible":true
   },
   {
      "fieldName":"cellphone",
      "label":"Cell Phone",
      "isEditable":true,
      "visible":true
   },
   {
      "fieldName":"email",
      "label":"Email",
      "isEditable":true,
      "visible":true
   },
   {
      "fieldName":"sms",
      "label":"SMS or Text",
      "isEditable":true,
      "visible":true
   },
   {
      "fieldName":"represent",
      "label":"Owner / Occupant",
      "isEditable":true,
      "visible":true
   },
   {
      "fieldName":"busopen",
      "label":"Business Open",
      "isEditable":true,
      "visible":true
   },
   {
      "fieldName":"daysclose",
      "label":"Number of Days Closed",
      "isEditable":true,
      "visible":true
   },
   {
      "fieldName":"strinsur",
      "label":"Structure Insured",
      "isEditable":true,
      "visible":true
   },
   {
      "fieldName":"continsur",
      "label":"Contents Insured",
      "isEditable":true,
      "visible":true
   },
   {
      "fieldName":"rentinsur",
      "label":"Renter's Insurance",
      "isEditable":true,
      "visible":true
   },
   {
      "fieldName":"earinsur",
      "label":"Earthquake Coverage",
      "isEditable":true,
      "visible":true
   },
   {
      "fieldName":"floodinsur",
      "label":"Flood Coverage",
      "isEditable":true,
      "visible":true
   },
   {
      "fieldName":"fireinsur",
      "label":"Wildland Fire Coverage",
      "isEditable":true,
      "visible":true
   },
   {
      "fieldName":"businsur",
      "label":"Business Continuity Coverage",
      "isEditable":true,
      "visible":true
   },
   {
      "fieldName":"deduct",
      "label":"Insurance Deductible",
      "isEditable":true,
      "visible":true
   },
   {
      "fieldName":"predisval",
      "label":"Value Before Damage",
      "isEditable":true,
      "visible":true
   },
   {
      "fieldName":"strloss",
      "label":"Estimated $ Loss Structure",
      "isEditable":true,
      "visible":true
   },
   {
      "fieldName":"contloss",
      "label":"Estimated $ Loss Contents",
      "isEditable":true,
      "visible":true
   },
   {
      "fieldName":"typdamage",
      "label":"Extent of Damage",
      "isEditable":true,
      "visible":true
   },
   {
      "fieldName":"primcause",
      "label":"Primary Cause of Damage",
      "isEditable":true,
      "visible":true
   },
   {
      "fieldName":"descdamage",
      "label":"Description of Damage",
      "isEditable":true,
      "visible":true
   },
   {
      "fieldName":"impactjur",
      "label":"Impact to Jurisdiction",
      "isEditable":true,
      "visible":true
   },
   {
      "fieldName":"comments",
      "label":"Additional Comments",
      "isEditable":true,
      "visible":true
   },
   {
      "fieldName":"lastupdate",
      "label":"Last Update Date",
      "isEditable":true,
      "visible":true
   },
   {
      "fieldName":"lasteditor",
      "label":"Last Editor",
      "isEditable":true,
      "visible":true
   }
]
'''

# %%
# Desabilitar os campos da popup

fields2disable = ['objectid', 'incidentid', 'inspectid']

for layer in webmap.layers:
    disable_fields(layer, fields2disable)

# %%
# Salvando o mapa

title = "Testing ArcGIS API For Python"
typeof = "Web Map"
tags = ["PYTHON API"]

item_properties_dict = {"type": typeof,"title": title,"tags": tags, 'snippet':'Web Map publicado via script'}

webmap.save(item_properties_dict, folder="Maps")
# Out:
# <Item title:"Testing ArcGIS API For Python" type:Web Map owner:admin>

# %%
from IPython.display import Image
Image("map.png")
